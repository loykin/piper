# %%
import json
import os
from support.math_utils import scaled

with open(os.path.join(os.environ["PIPER_INPUT_DIR"], "seed", "seed.json"), encoding="utf-8") as src:
    seed = json.load(src)
features = {"values": scaled(seed["values"], seed["multiplier"])}
with open(os.path.join(os.environ["PIPER_OUTPUT_DIR"], "features.json"), "w", encoding="utf-8") as dst:
    json.dump(features, dst)
